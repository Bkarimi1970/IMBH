# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
x1 =[38.5, 38.7, 38.8, 38.9, 39.0, 39.1, 39.2, 39.3, 39.4, 39.5, 39.6, 39.7, 39.8, 39.9, 40.6]
y1= [3.82, 3.92, 3.97, 4.02, 4.06, 4.12, 4.17, 4.22, 4.27, 4.32, 4.37, 4.42, 4.47, 4.52, 4.87]
x2= [37.5, 37.7, 37.8, 37.9, 38.0, 38.1, 38.2, 38.3, 38.4, 38.5, 38.6, 38.7, 38.8, 39.6]
y2= [5.43,5.97, 6.12, 6.15, 6.20, 6.28, 6.36, 6.43, 6.50, 6.60, 6.66, 6.74, 6.82, 6.89] 
plt.scatter(x1, y1, c='b', marker='s', label='Bondi Model')  
plt.scatter(x2, y2, c='r', marker='o', label='FP Model')  
plt.xlabel(r'$\log_{10}(L_X\,[{\rm erg\,s}^{-1}$])') 
plt.ylabel(r'$\log_{10}(M_{BH}(M_\odot)$])') 
plt.legend(loc='upper right') 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
x1 =[3.82, 3.92, 3.97, 4.02, 4.06, 4.12, 4.17, 4.22, 4.27, 4.32, 4.37, 4.42, 4.47, 4.52, 4.87]
y1= [33.41, 33.60, 33.70, 33.80, 33.90, 34.00, 34.10, 34.20, 34.30, 34.40, 34.50, 34.60, 34.70, 34.80, 35.50]
x2= [5.43, 5.97, 6.12, 6.15, 6.20, 6.28,6.36, 6.43, 6.49,6.59, 6.66, 6.74, 6.82, 6.89, 7.05]
y2= [35.33, 35.33, 35.33, 35.33, 35.33,35.33,35.33, 35.33, 35.33, 35.33, 35.33, 35.34, 35.38,35.41, 35.84] 
plt.scatter(x1, y1, c='b', marker='s', label='Bondi Model')  
plt.scatter(x2, y2, c='r', marker='o', label='FP Model')  
plt.axhline(y=34, color='black', linestyle='-')  
plt.xlabel(r'$\log_{10}(M_{BH}(M_\odot)$])') 
plt.ylabel(r'$\log_{10}(L_R\,[{\rm erg\,s}^{-1}$])')  
plt.legend(loc='upper left') 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
x1 =[38.5, 38.7, 38.8, 38.9, 39.0,39.1, 39.2, 39.3, 39.4, 39.5, 39.6, 39.7, 39.8, 39.9, 40.6]
y1= [3.82, 3.92, 3.97, 4.02, 4.06, 4.12, 4.17, 4.22, 4.27, 4.32, 4.37, 4.42, 4.47, 4.52, 4.87]
x2= [37.5, 37.7, 37.8, 37.9, 38.0, 38.1, 38.2, 38.3, 38.4, 38.5, 38.6, 38.7, 38.8, 39.6]
y2= [6.89, 6.82, 6.74,6.66, 6.60, 6.50, 6.43, 6.36, 6.28, 6.20, 6.15, 6.12, 5.97, 5.43] 
plt.scatter(x1, y1, c='b', marker='s', label='Bondi Model')  
plt.scatter(x2, y2, c='r', marker='o', label='FP Model')  
plt.xlabel(r'$\log_{10}(L_X\,[{\rm erg\,s}^{-1}$])') 
plt.ylabel(r'$\log_{10}(M_{BH}(M_\odot)$])') 
plt.legend(loc='upper right') 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
x= [3.75, 4, 4.25, 4.5, 4.75, 5, 5.25, 5.5, 5.75, 6, 6.25, 6.5, 6.75, 7] 
y= [3.92, 3.97, 4.02, 4.06, 4.12, 4.17, 4.22, 4.27, 4.32, 4.37, 4.42, 4.47, 4.52, 4.87]  
plt.scatter(x,y)
plt.errorbar(x, y, fmt='o', ecolor= '0.1', color='black')   
plt.xlabel(r'$\log_{10} GC Stellar Mass (M_{*}(M_\odot)$)') 
plt.ylabel(r'$\log_{10}(M^B_{BH}(M_\odot)$])') 
font={'family':'normal', 'weight': 'bold', 'size':14}
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
x2= [28, 28, 28, 28, 28, 28, 28.04, 27.99, 28, 27.99, 28, 28.01, 28.05, 28.05, 28.416]
y2= [35.33, 35.33, 35.33, 35.33, 35.33, 35.33, 35.32, 35.32, 35.33, 35.347, 35.38, 35.33, 35.746, 35.33, 35.34] 
plt.scatter(x2, y2, c='r', marker='o', label='FP Model')  
plt.xlabel((r'$ 0.6 * \log_{10}(L_X\,[{\rm erg\,s}^{-1} + 0.78 * log_{10} (M_{BH}({M_\odot})$]'))
plt.ylabel(r'$\log_{10}(L_R\,[{\rm erg\,s}^{-1}$]') 
plt.legend(loc='upper right') 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
x1 =[26.079, 26.277, 26.376, 26.475,26.566, 26.673, 26.772, 26.871, 26.970, 27.069, 27.168, 27.267, 27.366, 27.465, 28.158]
y1= [33.41, 33.60, 33.70, 33.80, 33.90, 34.00, 34.10, 34.20, 34.30, 34.40, 34.50, 34.60, 34.70, 34.80, 35.50]
plt.scatter(x1, y1, c='b', marker='s', label='Bondi Model')   
plt.xlabel((r'$ 0.6 * \log_{10}L_X\,[{\rm erg\,s}^{-1}] + 0.78 * log_{10}[(M_{BH}({M_\odot})$]'))
plt.ylabel(r'$\log_{10}(L_R\,[{\rm erg\,s}^{-1}$]') 
plt.show()
